# %%
# %sql

use dw01.bronze;
create or replace temporary view v_Data_proyecto
using csv 
options (
  path = "/Volumes/dw01/bronze/basededatos/data_proyecto.csv",
  header = "true",
  delimiter = ";"
);

--create or replace table ProductSubCategory as 
--select * from v_ProductSubCategory;

# %%
# %sql 
SELECT `Customer Name`, `Address`, `City`, `State`, `Customer Type`, `Account Manager`
FROM v_Data_proyecto

# %%
# %sql 
SELECT `Customer Name`, `Account Manager`
FROM v_Data_proyecto

# %%
# %sql 
SELECT `Product Name`, `Order No`, `Order Date`, `Order Priority`, `Order Quantity`,`Sub Total`,`Discount %`,`Discount $`,`Order Total`,`Shipping Cost`,`Total`, `Customer Name`
FROM v_Data_proyecto

# %%
# %sql 
SELECT `Product Name`, `Cost Price`, `Retail Price`, `Profit Margin`
  FROM v_Data_proyecto

# %%
# %sql 
SELECT `Product Name` ,`Product Category`, `Product Container`
  FROM v_Data_proyecto

# %%
# %sql 
SELECT `Order No`, `Ship Mode`, `Ship Date`
FROM v_Data_proyecto
